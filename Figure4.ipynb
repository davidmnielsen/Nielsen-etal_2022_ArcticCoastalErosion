# %%
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
import pandas as pd

# %% [markdown]
# ## Data

# %% [markdown]
# ### MPI-ESM

# %%
ipath='figure_data/'
ifile='drivers_scenarios.nc'
ds = xr.open_dataset(ipath+ifile, decode_times=False)
years_hist = ds['time_hist'].values
years_scen = ds['time_scen'].values
years_full = ds['time_full'].values
ensmu_s585 = ds['ensmu_s585'].values
ensmu_s245 = ds['ensmu_s245'].values
ensmu_s126 = ds['ensmu_s126'].values
ensmu_hist = ds['ensmu_hist'].values
ensse_s585 = ds['ensse_s585'].values
ensse_s245 = ds['ensse_s245'].values
ensse_s126 = ds['ensse_s126'].values
ensse_hist = ds['ensse_hist'].values

# %% [markdown]
# ### Sensitivities

# %%
ds = xr.open_dataset('figure_data/sensitivities_26wlen_1000nboots.nc', 
                     decode_times=False)

regAA_boots_s245_mu = ds['regAA_boots_s245_mu'].values
regAA_boots_s245_se = ds['regAA_boots_s245_se'].values
regAA_boots_s585_mu = ds['regAA_boots_s585_mu'].values
regAA_boots_s585_se = ds['regAA_boots_s585_se'].values
regAA_boots_s126_mu = ds['regAA_boots_s126_mu'].values
regAA_boots_s126_se = ds['regAA_boots_s126_se'].values
corr_amst_boots_s245_mu = ds['corr_amst_boots_s245_mu'].values
corr_amst_boots_s245_se = ds['corr_amst_boots_s245_se'].values
corr_amst_boots_s585_mu = ds['corr_amst_boots_s585_mu'].values
corr_amst_boots_s585_se = ds['corr_amst_boots_s585_se'].values
corr_amst_boots_s126_mu = ds['corr_amst_boots_s126_mu'].values
corr_amst_boots_s126_se = ds['corr_amst_boots_s126_se'].values
gmst_trend_boots_s245_mu = ds['gmst_trend_boots_s245_mu'].values
gmst_trend_boots_s245_se = ds['gmst_trend_boots_s245_se'].values
gmst_trend_boots_s585_mu = ds['gmst_trend_boots_s585_mu'].values
gmst_trend_boots_s585_se = ds['gmst_trend_boots_s585_se'].values
gmst_trend_boots_s126_mu = ds['gmst_trend_boots_s126_mu'].values
gmst_trend_boots_s126_se = ds['gmst_trend_boots_s126_se'].values
amst_trend_boots_s245_mu = ds['amst_trend_boots_s245_mu'].values
amst_trend_boots_s245_se = ds['amst_trend_boots_s245_se'].values
amst_trend_boots_s585_mu = ds['amst_trend_boots_s585_mu'].values
amst_trend_boots_s585_se = ds['amst_trend_boots_s585_se'].values
amst_trend_boots_s126_mu = ds['amst_trend_boots_s126_mu'].values
amst_trend_boots_s126_se = ds['amst_trend_boots_s126_se'].values

ds = xr.open_dataset('figure_data/sensitivities_26wlen_1000nboots_drivers.nc', 
                     decode_times=False)

t_boots_s245_mu = ds['t_boots_s245_mu'].values
t_boots_s245_se = ds['t_boots_s245_se'].values
t_boots_s585_mu = ds['t_boots_s585_mu'].values
t_boots_s585_se = ds['t_boots_s585_se'].values
t_boots_s126_mu = ds['t_boots_s126_mu'].values
t_boots_s126_se = ds['t_boots_s126_se'].values

h_boots_s245_mu = ds['h_boots_s245_mu'].values
h_boots_s245_se = ds['h_boots_s245_se'].values
h_boots_s585_mu = ds['h_boots_s585_mu'].values
h_boots_s585_se = ds['h_boots_s585_se'].values
h_boots_s126_mu = ds['h_boots_s126_mu'].values
h_boots_s126_se = ds['h_boots_s126_se'].values

# %% [markdown]
# ## Figures

# %%
def nospines(ax):
    import matplotlib.pyplot as plt
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.yaxis.set_ticks_position('left')
    ax.xaxis.set_ticks_position('bottom')
    
def leg(loc='best', fontsize='small', frameon=False):
    import matplotlib.pyplot as plt
    plt.legend(loc=loc, frameon=frameon, fontsize=fontsize)

# %%
wlen=26
AAOns = 112
years_hist = np.arange(1850,2015)+wlen/2-1
years_scen = np.arange(2015,2101)+wlen/2-1
years_full = np.arange(1850,2101)+wlen/2-1


fig = plt.figure(figsize=(4.5,7.0), dpi=140)

ax = fig.add_subplot(423)
plt.axhline(1, c='k', lw=1, ls='-')
plt.fill_between(years_hist[:-int(wlen/2)], 
                 regAA_boots_s126_mu[:int(len(years_hist)-wlen/2)]-2*regAA_boots_s126_se[:int(len(years_hist)-wlen/2)], 
                 regAA_boots_s126_mu[:int(len(years_hist)-wlen/2)]+2*regAA_boots_s126_se[:int(len(years_hist)-wlen/2)], 
                 facecolor='k', alpha=0.1, edgecolor=None)
plt.fill_between(years_hist[:-int(wlen/2)], 
                 regAA_boots_s245_mu[:int(len(years_hist)-wlen/2)]-2*regAA_boots_s245_se[:int(len(years_hist)-wlen/2)], 
                 regAA_boots_s245_mu[:int(len(years_hist)-wlen/2)]+2*regAA_boots_s245_se[:int(len(years_hist)-wlen/2)], 
                 facecolor='k', alpha=0.1, edgecolor=None)
plt.fill_between(years_hist[:-int(wlen/2)], 
                 regAA_boots_s585_mu[:int(len(years_hist)-wlen/2)]-2*regAA_boots_s585_se[:int(len(years_hist)-wlen/2)], 
                 regAA_boots_s585_mu[:int(len(years_hist)-wlen/2)]+2*regAA_boots_s585_se[:int(len(years_hist)-wlen/2)], 
                 facecolor='k', alpha=0.1, edgecolor=None)
plt.fill_between(years_full[int(len(years_hist)-wlen/2):], 
                 regAA_boots_s126_mu[int(len(years_hist)-wlen/2):]-2*regAA_boots_s126_se[int(len(years_hist)-wlen/2):], 
                 regAA_boots_s126_mu[int(len(years_hist)-wlen/2):]+2*regAA_boots_s126_se[int(len(years_hist)-wlen/2):], 
                 facecolor='b', alpha=0.2, edgecolor=None)
plt.fill_between(years_full[int(len(years_hist)-wlen/2):], 
                 regAA_boots_s245_mu[int(len(years_hist)-wlen/2):]-2*regAA_boots_s245_se[int(len(years_hist)-wlen/2):], 
                 regAA_boots_s245_mu[int(len(years_hist)-wlen/2):]+2*regAA_boots_s245_se[int(len(years_hist)-wlen/2):], 
                 facecolor='orange', alpha=0.4, edgecolor=None)
plt.fill_between(years_full[int(len(years_hist)-wlen/2):], 
                 regAA_boots_s585_mu[int(len(years_hist)-wlen/2):]-2*regAA_boots_s585_se[int(len(years_hist)-wlen/2):], 
                 regAA_boots_s585_mu[int(len(years_hist)-wlen/2):]+2*regAA_boots_s585_se[int(len(years_hist)-wlen/2):], 
                 facecolor='r', alpha=0.4, edgecolor=None)
plt.plot(years_full, regAA_boots_s126_mu,'w', ls='-', lw=1.7)
plt.plot(years_full, regAA_boots_s245_mu,'w', ls='-', lw=1.7)
plt.plot(years_full, regAA_boots_s585_mu,'w', ls='-', lw=1.7)
plt.plot(years_full[int(len(years_hist)-wlen/2):], regAA_boots_s126_mu[int(len(years_hist)-wlen/2):], 'w', ls='-', lw=1.7)
plt.plot(years_full[int(len(years_hist)-wlen/2):], regAA_boots_s245_mu[int(len(years_hist)-wlen/2):], 'w', ls='-', lw=1.7)
plt.plot(years_full[int(len(years_hist)-wlen/2):], regAA_boots_s585_mu[int(len(years_hist)-wlen/2):], 'w', ls='-', lw=1.7)
plt.plot(years_full, regAA_boots_s126_mu,'k', ls='-', lw=1)
plt.plot(years_full, regAA_boots_s245_mu,'k', ls='-', lw=1)
plt.plot(years_full, regAA_boots_s585_mu,'k', ls='-', lw=1)
plt.plot(years_full[int(len(years_hist)-wlen/2):], regAA_boots_s126_mu[int(len(years_hist)-wlen/2):], 'b', ls='-', lw=1)
plt.plot(years_full[int(len(years_hist)-wlen/2):], regAA_boots_s245_mu[int(len(years_hist)-wlen/2):], 'darkorange', ls='-', lw=1)
plt.plot(years_full[int(len(years_hist)-wlen/2):], regAA_boots_s585_mu[int(len(years_hist)-wlen/2):], 'r', ls='-', lw=1)
plt.title('Arctic Amplification Factor', fontsize=8, loc='left')
plt.xlim((1850,2100))
plt.ylabel(r'°C °C$^{-1}$', fontsize=8)
plt.yticks(np.arange(-1, 6, 1), np.arange(-1, 6, 1), fontsize=8)
plt.xticks(np.arange(1850,2150,50),np.arange(1850,2150,50),fontsize=8)
plt.ylim((-1.7,4.5))
plt.axvline(1850+wlen/2+AAOns, ls='--', lw=1, c='m')
plt.text(1850+wlen/2+AAOns+2, -1.1, 'AA Onset', c='m', fontsize=8)

ax = fig.add_subplot(425)
plt.axhline(0, c='k', lw=1, ls='-')
plt.fill_between(years_hist[:-int(wlen/2)], 
                 corr_amst_boots_s585_mu[:int(len(years_hist)-wlen/2)]-2*corr_amst_boots_s126_se[:int(len(years_hist)-wlen/2)], 
                 corr_amst_boots_s585_mu[:int(len(years_hist)-wlen/2)]+2*corr_amst_boots_s126_se[:int(len(years_hist)-wlen/2)], 
                 facecolor='k', alpha=0.1, edgecolor=None)
plt.fill_between(years_hist[:-int(wlen/2)], 
                 corr_amst_boots_s245_mu[:int(len(years_hist)-wlen/2)]-2*corr_amst_boots_s245_se[:int(len(years_hist)-wlen/2)], 
                 corr_amst_boots_s245_mu[:int(len(years_hist)-wlen/2)]+2*corr_amst_boots_s245_se[:int(len(years_hist)-wlen/2)], 
                 facecolor='k', alpha=0.1, edgecolor=None)
plt.fill_between(years_hist[:-int(wlen/2)], 
                 corr_amst_boots_s585_mu[:int(len(years_hist)-wlen/2)]-2*corr_amst_boots_s585_se[:int(len(years_hist)-wlen/2)], 
                 corr_amst_boots_s585_mu[:int(len(years_hist)-wlen/2)]+2*corr_amst_boots_s585_se[:int(len(years_hist)-wlen/2)], 
                 facecolor='k', alpha=0.1, edgecolor=None)
plt.fill_between(years_full[int(len(years_hist)-wlen/2):], 
                 corr_amst_boots_s126_mu[int(len(years_hist)-wlen/2):]-2*corr_amst_boots_s126_se[int(len(years_hist)-wlen/2):], 
                 corr_amst_boots_s126_mu[int(len(years_hist)-wlen/2):]+2*corr_amst_boots_s126_se[int(len(years_hist)-wlen/2):], 
                 facecolor='b', alpha=0.2, edgecolor=None)
plt.fill_between(years_full[int(len(years_hist)-wlen/2):], 
                 corr_amst_boots_s245_mu[int(len(years_hist)-wlen/2):]-2*corr_amst_boots_s245_se[int(len(years_hist)-wlen/2):], 
                 corr_amst_boots_s245_mu[int(len(years_hist)-wlen/2):]+2*corr_amst_boots_s245_se[int(len(years_hist)-wlen/2):], 
                 facecolor='orange', alpha=0.4, edgecolor=None)
plt.fill_between(years_full[int(len(years_hist)-wlen/2):], 
                 corr_amst_boots_s585_mu[int(len(years_hist)-wlen/2):]-2*corr_amst_boots_s585_se[int(len(years_hist)-wlen/2):], 
                 corr_amst_boots_s585_mu[int(len(years_hist)-wlen/2):]+2*corr_amst_boots_s585_se[int(len(years_hist)-wlen/2):], 
                 facecolor='r', alpha=0.4, edgecolor=None)
plt.plot(years_full, corr_amst_boots_s126_mu,'w', ls='-', lw=1.7)
plt.plot(years_full, corr_amst_boots_s245_mu,'w', ls='-', lw=1.7)
plt.plot(years_full, corr_amst_boots_s585_mu,'w', ls='-', lw=1.7)
plt.plot(years_full[int(len(years_hist)-wlen/2):], corr_amst_boots_s126_mu[int(len(years_hist)-wlen/2):], 'w', ls='-', lw=1.7)
plt.plot(years_full[int(len(years_hist)-wlen/2):], corr_amst_boots_s245_mu[int(len(years_hist)-wlen/2):], 'w', ls='-', lw=1.7)
plt.plot(years_full[int(len(years_hist)-wlen/2):], corr_amst_boots_s585_mu[int(len(years_hist)-wlen/2):], 'w', ls='-', lw=1.7)
plt.plot(years_full, corr_amst_boots_s126_mu,'k', ls='-', lw=1)
plt.plot(years_full, corr_amst_boots_s245_mu,'k', ls='-', lw=1)
plt.plot(years_full, corr_amst_boots_s585_mu,'k', ls='-', lw=1)
plt.plot(years_full[int(len(years_hist)-wlen/2):], corr_amst_boots_s126_mu[int(len(years_hist)-wlen/2):], 'b', ls='-', lw=1)
plt.plot(years_full[int(len(years_hist)-wlen/2):], corr_amst_boots_s245_mu[int(len(years_hist)-wlen/2):], 'darkorange', ls='-', lw=1)
plt.plot(years_full[int(len(years_hist)-wlen/2):], corr_amst_boots_s585_mu[int(len(years_hist)-wlen/2):], 'r', ls='-', lw=1)
plt.yticks(np.arange(-1, 1.5, 0.5), [ np.round(i,2) for i in np.arange(-1, 1.5, 0.5)], fontsize=8)
plt.xticks(np.arange(1850,2150,50),np.arange(1850,2150,50),fontsize=8)
plt.ylim((-0.5,1.0))
plt.xlim((1850,2100))
plt.ylabel(r'')
plt.title('Correlation Erosion vs. Arctic SAT', fontsize=8, loc='left')
plt.axvline(1850+wlen/2+AAOns, ls='--', lw=1, c='m')


ax = fig.add_subplot(427)
plt.axhline(0, c='k', lw=1, ls='-')
plt.fill_between(years_hist[:-int(wlen/2)], 
                 10*gmst_trend_boots_s126_mu[:int(len(years_hist)-wlen/2)]-2*10*gmst_trend_boots_s126_se[:int(len(years_hist)-wlen/2)], 
                 10*gmst_trend_boots_s126_mu[:int(len(years_hist)-wlen/2)]+2*10*gmst_trend_boots_s126_se[:int(len(years_hist)-wlen/2)], 
                 facecolor='k', alpha=0.1, edgecolor=None)
plt.fill_between(years_hist[:-int(wlen/2)], 
                 10*gmst_trend_boots_s245_mu[:int(len(years_hist)-wlen/2)]-2*10*gmst_trend_boots_s245_se[:int(len(years_hist)-wlen/2)], 
                 10*gmst_trend_boots_s245_mu[:int(len(years_hist)-wlen/2)]+2*10*gmst_trend_boots_s245_se[:int(len(years_hist)-wlen/2)], 
                 facecolor='k', alpha=0.1, edgecolor=None)
plt.fill_between(years_hist[:-int(wlen/2)], 
                 10*gmst_trend_boots_s585_mu[:int(len(years_hist)-wlen/2)]-2*10*gmst_trend_boots_s585_se[:int(len(years_hist)-wlen/2)], 
                 10*gmst_trend_boots_s585_mu[:int(len(years_hist)-wlen/2)]+2*10*gmst_trend_boots_s585_se[:int(len(years_hist)-wlen/2)], 
                 facecolor='k', alpha=0.1, edgecolor=None)
plt.fill_between(years_full[int(len(years_hist)-wlen/2):], 
                 10*gmst_trend_boots_s126_mu[int(len(years_hist)-wlen/2):]-2*10*gmst_trend_boots_s126_se[int(len(years_hist)-wlen/2):], 
                 10*gmst_trend_boots_s126_mu[int(len(years_hist)-wlen/2):]+2*10*gmst_trend_boots_s126_se[int(len(years_hist)-wlen/2):], 
                 facecolor='b', alpha=0.2, edgecolor=None)
plt.fill_between(years_full[int(len(years_hist)-wlen/2):], 
                 10*gmst_trend_boots_s245_mu[int(len(years_hist)-wlen/2):]-2*10*gmst_trend_boots_s245_se[int(len(years_hist)-wlen/2):], 
                 10*gmst_trend_boots_s245_mu[int(len(years_hist)-wlen/2):]+2*10*gmst_trend_boots_s245_se[int(len(years_hist)-wlen/2):], 
                 facecolor='orange', alpha=0.4, edgecolor=None)
plt.fill_between(years_full[int(len(years_hist)-wlen/2):], 
                 10*gmst_trend_boots_s585_mu[int(len(years_hist)-wlen/2):]-2*10*gmst_trend_boots_s585_se[int(len(years_hist)-wlen/2):], 
                 10*gmst_trend_boots_s585_mu[int(len(years_hist)-wlen/2):]+2*10*gmst_trend_boots_s585_se[int(len(years_hist)-wlen/2):], 
                 facecolor='r', alpha=0.4, edgecolor=None)
plt.plot(years_full, 10*gmst_trend_boots_s126_mu,'w', ls='-', lw=1.5)
plt.plot(years_full, 10*gmst_trend_boots_s245_mu,'w', ls='-', lw=1.5)
plt.plot(years_full, 10*gmst_trend_boots_s585_mu,'w', ls='-', lw=1.5)
plt.plot(years_hist[:-int(wlen/2)], 10*gmst_trend_boots_s126_mu[:int(len(years_hist)-wlen/2)],'k', ls='--', lw=1)
plt.plot(years_hist[:-int(wlen/2)], 10*gmst_trend_boots_s245_mu[:int(len(years_hist)-wlen/2)],'k', ls='--', lw=1)
plt.plot(years_hist[:-int(wlen/2)], 10*gmst_trend_boots_s585_mu[:int(len(years_hist)-wlen/2)],'k', ls='--', lw=1, label='Global SAT')
plt.plot(years_full[int(len(years_hist)-wlen/2):], 10*gmst_trend_boots_s126_mu[int(len(years_hist)-wlen/2):], 'b', ls='--', lw=1)
plt.plot(years_full[int(len(years_hist)-wlen/2):], 10*gmst_trend_boots_s245_mu[int(len(years_hist)-wlen/2):], 'darkorange', ls='--', lw=1)
plt.plot(years_full[int(len(years_hist)-wlen/2):], 10*gmst_trend_boots_s585_mu[int(len(years_hist)-wlen/2):], 'r', ls='--', lw=1)
plt.fill_between(years_hist[:-int(wlen/2)], 
                 10*amst_trend_boots_s126_mu[:int(len(years_hist)-wlen/2)]-2*10*amst_trend_boots_s126_se[:int(len(years_hist)-wlen/2)], 
                 10*amst_trend_boots_s126_mu[:int(len(years_hist)-wlen/2)]+2*10*amst_trend_boots_s126_se[:int(len(years_hist)-wlen/2)], 
                 facecolor='k', alpha=0.2, edgecolor=None)
plt.fill_between(years_hist[:-int(wlen/2)], 
                 10*amst_trend_boots_s245_mu[:int(len(years_hist)-wlen/2)]-2*10*amst_trend_boots_s245_se[:int(len(years_hist)-wlen/2)], 
                 10*amst_trend_boots_s245_mu[:int(len(years_hist)-wlen/2)]+2*10*amst_trend_boots_s245_se[:int(len(years_hist)-wlen/2)], 
                 facecolor='k', alpha=0.2, edgecolor=None)
plt.fill_between(years_hist[:-int(wlen/2)], 
                 10*amst_trend_boots_s585_mu[:int(len(years_hist)-wlen/2)]-2*10*amst_trend_boots_s585_se[:int(len(years_hist)-wlen/2)], 
                 10*amst_trend_boots_s585_mu[:int(len(years_hist)-wlen/2)]+2*10*amst_trend_boots_s585_se[:int(len(years_hist)-wlen/2)], 
                 facecolor='k', alpha=0.2, edgecolor=None)
plt.fill_between(years_full[int(len(years_hist)-wlen/2):], 
                 10*amst_trend_boots_s126_mu[int(len(years_hist)-wlen/2):]-2*10*amst_trend_boots_s126_se[int(len(years_hist)-wlen/2):], 
                 10*amst_trend_boots_s126_mu[int(len(years_hist)-wlen/2):]+2*10*amst_trend_boots_s126_se[int(len(years_hist)-wlen/2):], 
                 facecolor='b', alpha=0.2, edgecolor=None)
plt.fill_between(years_full[int(len(years_hist)-wlen/2):], 
                 10*amst_trend_boots_s245_mu[int(len(years_hist)-wlen/2):]-2*10*amst_trend_boots_s245_se[int(len(years_hist)-wlen/2):], 
                 10*amst_trend_boots_s245_mu[int(len(years_hist)-wlen/2):]+2*10*amst_trend_boots_s245_se[int(len(years_hist)-wlen/2):], 
                 facecolor='orange', alpha=0.4, edgecolor=None)
plt.fill_between(years_full[int(len(years_hist)-wlen/2):], 
                 10*amst_trend_boots_s585_mu[int(len(years_hist)-wlen/2):]-2*10*amst_trend_boots_s585_se[int(len(years_hist)-wlen/2):], 
                 10*amst_trend_boots_s585_mu[int(len(years_hist)-wlen/2):]+2*10*amst_trend_boots_s585_se[int(len(years_hist)-wlen/2):], 
                 facecolor='r', alpha=0.4, edgecolor=None)
plt.plot(years_full, 10*amst_trend_boots_s245_mu,'w', ls='-', lw=1.7)
plt.plot(years_full, 10*amst_trend_boots_s126_mu,'w', ls='-', lw=1.7)
plt.plot(years_full, 10*amst_trend_boots_s585_mu,'w', ls='-', lw=1.7)
plt.plot(years_full, 10*amst_trend_boots_s126_mu,'k', ls='-', lw=1)
plt.plot(years_full, 10*amst_trend_boots_s245_mu,'k', ls='-', lw=1)
plt.plot(years_full, 10*amst_trend_boots_s585_mu,'k', ls='-', lw=1, label='Arctic SAT')
plt.plot(years_full[int(len(years_hist)-wlen/2):], 10*amst_trend_boots_s126_mu[int(len(years_hist)-wlen/2):], 'w', ls='-', lw=1.7)
plt.plot(years_full[int(len(years_hist)-wlen/2):], 10*amst_trend_boots_s245_mu[int(len(years_hist)-wlen/2):], 'w', ls='-', lw=1.7)
plt.plot(years_full[int(len(years_hist)-wlen/2):], 10*amst_trend_boots_s585_mu[int(len(years_hist)-wlen/2):], 'w', ls='-', lw=1.7)
plt.plot(years_full[int(len(years_hist)-wlen/2):], 10*amst_trend_boots_s126_mu[int(len(years_hist)-wlen/2):], 'b', ls='-', lw=1)
plt.plot(years_full[int(len(years_hist)-wlen/2):], 10*amst_trend_boots_s245_mu[int(len(years_hist)-wlen/2):], 'darkorange', ls='-', lw=1)
plt.plot(years_full[int(len(years_hist)-wlen/2):], 10*amst_trend_boots_s585_mu[int(len(years_hist)-wlen/2):], 'r', ls='-', lw=1)
plt.yticks(np.arange(-0.8, 1.6, 0.4), [ np.round(i,2) for i in np.arange(-0.8, 1.6, 0.4)], fontsize=8)
plt.xticks(np.arange(1850,2150,50),np.arange(1850,2150,50),fontsize=8)
plt.ylim((-0.4,1.4))
plt.xlim((1850,2100))
plt.ylabel(r'°C decade$^{-1}$', fontsize=8)
plt.title('Trends', fontsize=8, loc='left')
plt.axvline(1850+wlen/2+AAOns, ls='--', lw=1, c='m')
leg(fontsize=7)

plt.tight_layout()
fig.subplots_adjust(hspace=0.5, wspace=-0.18)
plt.show()

# %%
fig = plt.figure(figsize=(4.5,7.0), dpi=140)

ax = fig.add_subplot(421)
plt.axhline(0, c='k', lw=1)
plt.fill_between(years_hist[:-int(wlen/2)], 
                 t_boots_s245_mu[:int(len(years_hist)-wlen/2)]-2*t_boots_s245_se[:int(len(years_hist)-wlen/2)], 
                 t_boots_s245_mu[:int(len(years_hist)-wlen/2)]+2*t_boots_s245_se[:int(len(years_hist)-wlen/2)], 
                 facecolor='k', alpha=0.1, edgecolor=None)
plt.fill_between(years_hist[:-int(wlen/2)], 
                 t_boots_s585_mu[:int(len(years_hist)-wlen/2)]-2*t_boots_s585_se[:int(len(years_hist)-wlen/2)], 
                 t_boots_s585_mu[:int(len(years_hist)-wlen/2)]+2*t_boots_s585_se[:int(len(years_hist)-wlen/2)], 
                 facecolor='k', alpha=0.1, edgecolor=None)
plt.fill_between(years_hist[:-int(wlen/2)], 
                 t_boots_s126_mu[:int(len(years_hist)-wlen/2)]-2*t_boots_s126_se[:int(len(years_hist)-wlen/2)], 
                 t_boots_s126_mu[:int(len(years_hist)-wlen/2)]+2*t_boots_s126_se[:int(len(years_hist)-wlen/2)], 
                 facecolor='k', alpha=0.1, edgecolor=None)
plt.fill_between(years_full[int(len(years_hist)-wlen/2):], 
                 t_boots_s126_mu[int(len(years_hist)-wlen/2):]-2*t_boots_s126_se[int(len(years_hist)-wlen/2):], 
                 t_boots_s126_mu[int(len(years_hist)-wlen/2):]+2*t_boots_s126_se[int(len(years_hist)-wlen/2):], 
                 facecolor='b', alpha=0.2, edgecolor=None)
plt.fill_between(years_full[int(len(years_hist)-wlen/2):], 
                 t_boots_s245_mu[int(len(years_hist)-wlen/2):]-2*t_boots_s245_se[int(len(years_hist)-wlen/2):], 
                 t_boots_s245_mu[int(len(years_hist)-wlen/2):]+2*t_boots_s245_se[int(len(years_hist)-wlen/2):], 
                 facecolor='orange', alpha=0.4, edgecolor=None)
plt.fill_between(years_full[int(len(years_hist)-wlen/2):], 
                 t_boots_s585_mu[int(len(years_hist)-wlen/2):]-2*t_boots_s585_se[int(len(years_hist)-wlen/2):], 
                 t_boots_s585_mu[int(len(years_hist)-wlen/2):]+2*t_boots_s585_se[int(len(years_hist)-wlen/2):], 
                 facecolor='r', alpha=0.4, edgecolor=None)
plt.plot(years_full, t_boots_s126_mu,'w', ls='-', lw=1.7)
plt.plot(years_full, t_boots_s245_mu,'w', ls='-', lw=1.7)
plt.plot(years_full, t_boots_s585_mu,'w', ls='-', lw=1.7)
plt.plot(years_full[int(len(years_hist)-wlen/2):], t_boots_s126_mu[int(len(years_hist)-wlen/2):], 'w', ls='-', lw=1.7)
plt.plot(years_full[int(len(years_hist)-wlen/2):], t_boots_s245_mu[int(len(years_hist)-wlen/2):], 'w', ls='-', lw=1.7)
plt.plot(years_full[int(len(years_hist)-wlen/2):], t_boots_s585_mu[int(len(years_hist)-wlen/2):], 'w', ls='-', lw=1.7)
plt.plot(years_full, t_boots_s126_mu,'k', ls='-', lw=1)
plt.plot(years_full, t_boots_s245_mu,'k', ls='-', lw=1)
plt.plot(years_full, t_boots_s585_mu,'k', ls='-', lw=1)
plt.plot(years_full[int(len(years_hist)-wlen/2):], t_boots_s126_mu[int(len(years_hist)-wlen/2):], 'b', ls='-', lw=1)
plt.plot(years_full[int(len(years_hist)-wlen/2):], t_boots_s245_mu[int(len(years_hist)-wlen/2):], 'darkorange', ls='-', lw=1)
plt.plot(years_full[int(len(years_hist)-wlen/2):], t_boots_s585_mu[int(len(years_hist)-wlen/2):], 'r', ls='-', lw=1)
plt.xlim((1850,2100))
plt.title('Sensitivity of $\overline{T}$ to GMST', fontsize=8, loc='left')
plt.xlim((1850,2100))
plt.ylabel(r'°C day year$^{-1}$ °C$^{-1}$', fontsize=8)
plt.yticks(np.arange(-200, 1000, 200), np.arange(-200, 1000, 200), fontsize=8)
plt.xticks(np.arange(1850,2150,50),np.arange(1850,2150,50),fontsize=8)
plt.ylim((-200,600))
plt.axvline(1850+wlen/2+AAOns, ls='--', lw=1, c='m')


ax = fig.add_subplot(423)
plt.axhline(1, c='k', lw=1, ls='-')
plt.fill_between(years_hist[:-int(wlen/2)], 
                 h_boots_s126_mu[:int(len(years_hist)-wlen/2)]-2*h_boots_s126_se[:int(len(years_hist)-wlen/2)], 
                 h_boots_s126_mu[:int(len(years_hist)-wlen/2)]+2*h_boots_s126_se[:int(len(years_hist)-wlen/2)], 
                 facecolor='k', alpha=0.1, edgecolor=None)
plt.fill_between(years_hist[:-int(wlen/2)], 
                 h_boots_s245_mu[:int(len(years_hist)-wlen/2)]-2*h_boots_s245_se[:int(len(years_hist)-wlen/2)], 
                 h_boots_s245_mu[:int(len(years_hist)-wlen/2)]+2*h_boots_s245_se[:int(len(years_hist)-wlen/2)], 
                 facecolor='k', alpha=0.1, edgecolor=None)
plt.fill_between(years_hist[:-int(wlen/2)], 
                 h_boots_s585_mu[:int(len(years_hist)-wlen/2)]-2*h_boots_s585_se[:int(len(years_hist)-wlen/2)], 
                 h_boots_s585_mu[:int(len(years_hist)-wlen/2)]+2*h_boots_s585_se[:int(len(years_hist)-wlen/2)], 
                 facecolor='k', alpha=0.1, edgecolor=None)
plt.fill_between(years_full[int(len(years_hist)-wlen/2):], 
                 h_boots_s126_mu[int(len(years_hist)-wlen/2):]-2*h_boots_s126_se[int(len(years_hist)-wlen/2):], 
                 h_boots_s126_mu[int(len(years_hist)-wlen/2):]+2*h_boots_s126_se[int(len(years_hist)-wlen/2):], 
                 facecolor='b', alpha=0.2, edgecolor=None)
plt.fill_between(years_full[int(len(years_hist)-wlen/2):], 
                 h_boots_s245_mu[int(len(years_hist)-wlen/2):]-2*h_boots_s245_se[int(len(years_hist)-wlen/2):], 
                 h_boots_s245_mu[int(len(years_hist)-wlen/2):]+2*h_boots_s245_se[int(len(years_hist)-wlen/2):], 
                 facecolor='orange', alpha=0.4, edgecolor=None)
plt.fill_between(years_full[int(len(years_hist)-wlen/2):], 
                 h_boots_s585_mu[int(len(years_hist)-wlen/2):]-2*h_boots_s585_se[int(len(years_hist)-wlen/2):], 
                 h_boots_s585_mu[int(len(years_hist)-wlen/2):]+2*h_boots_s585_se[int(len(years_hist)-wlen/2):], 
                 facecolor='r', alpha=0.4, edgecolor=None)
plt.plot(years_full, h_boots_s126_mu,'w', ls='-', lw=1.7)
plt.plot(years_full, h_boots_s245_mu,'w', ls='-', lw=1.7)
plt.plot(years_full, h_boots_s585_mu,'w', ls='-', lw=1.7)
plt.plot(years_full[int(len(years_hist)-wlen/2):], h_boots_s126_mu[int(len(years_hist)-wlen/2):], 'w', ls='-', lw=1.7)
plt.plot(years_full[int(len(years_hist)-wlen/2):], h_boots_s245_mu[int(len(years_hist)-wlen/2):], 'w', ls='-', lw=1.7)
plt.plot(years_full[int(len(years_hist)-wlen/2):], h_boots_s585_mu[int(len(years_hist)-wlen/2):], 'w', ls='-', lw=1.7)
plt.plot(years_full, h_boots_s126_mu,'k', ls='-', lw=1)
plt.plot(years_full, h_boots_s245_mu,'k', ls='-', lw=1)
plt.plot(years_full, h_boots_s585_mu,'k', ls='-', lw=1)
plt.plot(years_full[int(len(years_hist)-wlen/2):], h_boots_s126_mu[int(len(years_hist)-wlen/2):], 'b', ls='-', lw=1)
plt.plot(years_full[int(len(years_hist)-wlen/2):], h_boots_s245_mu[int(len(years_hist)-wlen/2):], 'darkorange', ls='-', lw=1)
plt.plot(years_full[int(len(years_hist)-wlen/2):], h_boots_s585_mu[int(len(years_hist)-wlen/2):], 'r', ls='-', lw=1)
plt.title('Sensitivity of $\overline{H}$ to GMST', fontsize=8, loc='left')
plt.xlim((1850,2100))
plt.ylabel(r'm day year$^{-1}$ °C$^{-1}$', fontsize=8)
plt.yticks(np.arange(-50, 500, 50), np.arange(-50, 500, 50),  fontsize=8)
plt.xticks(np.arange(1850,2150,50),np.arange(1850,2150,50),fontsize=8)
plt.ylim((-50,100))
plt.axvline(1850+wlen/2+AAOns, ls='--', lw=1, c='m')

plt.tight_layout()
fig.subplots_adjust(hspace=0.5, wspace=-0.18)
plt.show()

# %%
fig = plt.figure(figsize=(4,7.0), dpi=200)

ms=0.5
ax = fig.add_subplot(427) #427

ref0=np.mean(ensmu_hist[0,:100])
ref1=np.mean(ensmu_hist[1,:100])

plt.errorbar(ensmu_hist[0,:]/ref0, ensmu_hist[1,:]/ref1, xerr=2*ensse_hist[0,:]/ref0, yerr=2*ensse_hist[1,:]/ref1,
             ecolor='grey', label='historical', ls='none', lw=0.1)
plt.plot(ensmu_hist[0,:]/ref0, ensmu_hist[1,:]/ref1, 'ok', ms=ms)
plt.errorbar(ensmu_s126[0,:]/ref0, ensmu_s126[1,:]/ref1, xerr=2*ensse_s126[0,:]/ref0, yerr=2*ensse_s126[1,:]/ref1,
             ecolor='b', label='historical', ls='none', lw=0.1)
plt.plot(ensmu_s126[0,:]/ref0, ensmu_s126[1,:]/ref1, 'o', c='b', ms=ms)
plt.errorbar(ensmu_s245[0,:]/ref0, ensmu_s245[1,:]/ref1, xerr=2*ensse_s245[0,:]/ref0, yerr=2*ensse_s245[1,:]/ref1,
             ecolor='orange', label='historical', ls='none', lw=0.1)
plt.plot(ensmu_s245[0,:]/ref0, ensmu_s245[1,:]/ref1, 'o', c='orange', ms=ms)
plt.errorbar(ensmu_s585[0,:]/ref0, ensmu_s585[1,:]/ref1, xerr=2*ensse_s585[0,:]/ref0, yerr=2*ensse_s585[1,:]/ref1,
             ecolor='r', label='historical', ls='none', lw=0.1)
plt.plot(ensmu_s585[0,:]/ref0, ensmu_s585[1,:]/ref1, 'o', c='r', ms=ms)

plt.plot(np.arange(0,3.5,0.1),np.arange(0,3.5,0.1),ls='--',c='grey',lw=1)
plt.xticks(np.arange(0, 4, 1),fontsize=8)
plt.yticks(np.arange(0, 4, 1),fontsize=8)
plt.xlim((0.6,3.0))
plt.ylim((0.6,3.0))
plt.xlabel(r'$\overline{T}(t)/\overline{T}_{hist}$',fontsize=8)
plt.ylabel(r'$\overline{H}(t)/\overline{H}_{hist}$',fontsize=8)

plt.tight_layout()
plt.show()
