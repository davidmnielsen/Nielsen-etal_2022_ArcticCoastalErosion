# %%
import numpy as np
import matplotlib.pyplot as plt
import xarray as xr
import pandas as pd
from scipy import stats

# %% [markdown]
# ## Data

# %% [markdown]
# ### MPI-ESM

# %%
ipath='figure_data/'
ifile='drivers_scenarios.nc'
ds = xr.open_dataset(ipath+ifile, decode_times=False)
years_hist = ds['time_hist'].values
years_scen = ds['time_scen'].values
years_full = ds['time_full'].values
ensmu_s585 = ds['ensmu_s585'].values
ensmu_s245 = ds['ensmu_s245'].values
ensmu_s126 = ds['ensmu_s126'].values
ensmu_hist = ds['ensmu_hist'].values
ensse_s585 = ds['ensse_s585'].values
ensse_s245 = ds['ensse_s245'].values
ensse_s126 = ds['ensse_s126'].values
ensse_hist = ds['ensse_hist'].values

# %% [markdown]
# ### Erosion

# %%
ipath='/work/uo1075/u241292/data/NCC_data/DKRZ_DOKU/'

scenstr="ssp126"

qstr="0.10"
ifile="eros_ACD-segments_"+scenstr+"_q"+qstr+".nc"
ds = xr.open_dataset(ipath+ifile, decode_times=False)
seglen = ds['SegLen'].values
erosmu_s126_01 = np.average(ds['eros'].values, weights=seglen, axis=1)[146:]
erosse_s126_01 = np.average(ds['unc_ensemble'].values, weights=seglen, axis=1)[146:] + ds['unc_temporal'].values[146:]
eros_ensse_s126_01 = np.average(ds['unc_ensemble'].values, weights=seglen, axis=1)[146:]
eros_temse_s126_01 = ds['unc_temporal'].values[146:]

qstr="0.50"
ifile="eros_ACD-segments_"+scenstr+"_q"+qstr+".nc"
ds = xr.open_dataset(ipath+ifile, decode_times=False)
seglen = ds['SegLen'].values
erosmu_s126_05 = np.average(ds['eros'].values, weights=seglen, axis=1)[146:]
erosse_s126_05 = np.average(ds['unc_ensemble'].values, weights=seglen, axis=1)[146:] + ds['unc_temporal'].values[146:]
eros_ensse_s126_05 = np.average(ds['unc_ensemble'].values, weights=seglen, axis=1)[146:]
eros_temse_s126_05 = ds['unc_temporal'].values[146:]

qstr="0.90"
ifile="eros_ACD-segments_"+scenstr+"_q"+qstr+".nc"
ds = xr.open_dataset(ipath+ifile, decode_times=False)
seglen = ds['SegLen'].values
erosmu_s126_09 = np.average(ds['eros'].values, weights=seglen, axis=1)[146:]
erosse_s126_09 = np.average(ds['unc_ensemble'].values, weights=seglen, axis=1)[146:] + ds['unc_temporal'].values[146:]
eros_ensse_s126_09 = np.average(ds['unc_ensemble'].values, weights=seglen, axis=1)[146:]
eros_temse_s126_09 = ds['unc_temporal'].values[146:]

scenstr="ssp245"

qstr="0.10"
ifile="eros_ACD-segments_"+scenstr+"_q"+qstr+".nc"
ds = xr.open_dataset(ipath+ifile, decode_times=False)
seglen = ds['SegLen'].values
erosmu_hist_01 = np.average(ds['eros'].values, weights=seglen, axis=1)[:146]
erosmu_s245_01 = np.average(ds['eros'].values, weights=seglen, axis=1)[146:]
erosse_hist_01 = np.average(ds['unc_ensemble'].values, weights=seglen, axis=1)[:146] + ds['unc_temporal'].values[:146]
erosse_s245_01 = np.average(ds['unc_ensemble'].values, weights=seglen, axis=1)[146:] + ds['unc_temporal'].values[146:]
eros_ensse_hist_01 = np.average(ds['unc_ensemble'].values, weights=seglen, axis=1)[:146]
eros_ensse_s245_01 = np.average(ds['unc_ensemble'].values, weights=seglen, axis=1)[146:]
eros_temse_hist_01 = ds['unc_temporal'].values[:146]
eros_temse_s245_01 = ds['unc_temporal'].values[146:]

qstr="0.50"
ifile="eros_ACD-segments_"+scenstr+"_q"+qstr+".nc"
ds = xr.open_dataset(ipath+ifile, decode_times=False)
seglen = ds['SegLen'].values
erosmu_hist_05 = np.average(ds['eros'].values, weights=seglen, axis=1)[:146]
erosmu_s245_05 = np.average(ds['eros'].values, weights=seglen, axis=1)[146:]
erosse_hist_05 = np.average(ds['unc_ensemble'].values, weights=seglen, axis=1)[:146] + ds['unc_temporal'].values[:146] 
erosse_s245_05 = np.average(ds['unc_ensemble'].values, weights=seglen, axis=1)[146:] + ds['unc_temporal'].values[146:] 
eros_ensse_hist_05 = np.average(ds['unc_ensemble'].values, weights=seglen, axis=1)[:146]
eros_ensse_s245_05 = np.average(ds['unc_ensemble'].values, weights=seglen, axis=1)[146:]
eros_temse_hist_05 = ds['unc_temporal'].values[:146]
eros_temse_s245_05 = ds['unc_temporal'].values[146:]

qstr="0.90"
ifile="eros_ACD-segments_"+scenstr+"_q"+qstr+".nc"
ds = xr.open_dataset(ipath+ifile, decode_times=False)
seglen = ds['SegLen'].values
erosmu_hist_09 = np.average(ds['eros'].values, weights=seglen, axis=1)[:146]
erosmu_s245_09 = np.average(ds['eros'].values, weights=seglen, axis=1)[146:]
erosse_hist_09 = np.average(ds['unc_ensemble'].values, weights=seglen, axis=1)[:146] + ds['unc_temporal'].values[:146]
erosse_s245_09 = np.average(ds['unc_ensemble'].values, weights=seglen, axis=1)[146:] + ds['unc_temporal'].values[146:]
eros_ensse_hist_09 = np.average(ds['unc_ensemble'].values, weights=seglen, axis=1)[:146]
eros_ensse_s245_09 = np.average(ds['unc_ensemble'].values, weights=seglen, axis=1)[146:]
eros_temse_hist_09 = ds['unc_temporal'].values[:146]
eros_temse_s245_09 = ds['unc_temporal'].values[146:]

scenstr="ssp585"

qstr="0.10"
ifile="eros_ACD-segments_"+scenstr+"_q"+qstr+".nc"
ds = xr.open_dataset(ipath+ifile, decode_times=False)
seglen = ds['SegLen'].values
erosmu_s585_01 = np.average(ds['eros'].values, weights=seglen, axis=1)[146:]
erosse_s585_01 = np.average(ds['unc_ensemble'].values, weights=seglen, axis=1)[146:] + ds['unc_temporal'].values[146:]
eros_ensse_s585_01 = np.average(ds['unc_ensemble'].values, weights=seglen, axis=1)[146:]
eros_temse_s585_01 = ds['unc_temporal'].values[146:]

qstr="0.50"
ifile="eros_ACD-segments_"+scenstr+"_q"+qstr+".nc"
ds = xr.open_dataset(ipath+ifile, decode_times=False)
seglen = ds['SegLen'].values
erosmu_s585_05 = np.average(ds['eros'].values, weights=seglen, axis=1)[146:]
erosse_s585_05 = np.average(ds['unc_ensemble'].values, weights=seglen, axis=1)[146:] + ds['unc_temporal'].values[146:]
eros_ensse_s585_05 = np.average(ds['unc_ensemble'].values, weights=seglen, axis=1)[146:]
eros_temse_s585_05 = ds['unc_temporal'].values[146:]

qstr="0.90"
ifile="eros_ACD-segments_"+scenstr+"_q"+qstr+".nc"
ds = xr.open_dataset(ipath+ifile, decode_times=False)
seglen = ds['SegLen'].values
erosmu_s585_09 = np.average(ds['eros'].values, weights=seglen, axis=1)[146:]
erosse_s585_09 = np.average(ds['unc_ensemble'].values, weights=seglen, axis=1)[146:] + ds['unc_temporal'].values[146:]
eros_ensse_s585_09 = np.average(ds['unc_ensemble'].values, weights=seglen, axis=1)[146:]
eros_temse_s585_09 = ds['unc_temporal'].values[146:]


erosmu_hist = np.vstack([erosmu_hist_01,erosmu_hist_05,erosmu_hist_09]).T
erosmu_s245 = np.vstack([erosmu_s245_01,erosmu_s245_05,erosmu_s245_09]).T
erosmu_s585 = np.vstack([erosmu_s585_01,erosmu_s585_05,erosmu_s585_09]).T
erosmu_s126 = np.vstack([erosmu_s126_01,erosmu_s126_05,erosmu_s126_09]).T
erosse_hist = np.vstack([erosse_hist_01,erosse_hist_05,erosse_hist_09]).T
erosse_s245 = np.vstack([erosse_s245_01,erosse_s245_05,erosse_s245_09]).T
erosse_s585 = np.vstack([erosse_s585_01,erosse_s585_05,erosse_s585_09]).T
erosse_s126 = np.vstack([erosse_s126_01,erosse_s126_05,erosse_s126_09]).T
eros_ensse_hist = np.vstack([eros_ensse_hist_01,eros_ensse_hist_05,eros_ensse_hist_09]).T
eros_ensse_s245 = np.vstack([eros_ensse_s245_01,eros_ensse_s245_05,eros_ensse_s245_09]).T
eros_ensse_s585 = np.vstack([eros_ensse_s585_01,eros_ensse_s585_05,eros_ensse_s585_09]).T
eros_ensse_s126 = np.vstack([eros_ensse_s126_01,eros_ensse_s126_05,eros_ensse_s126_09]).T
eros_temse_hist = np.vstack([eros_temse_hist_01,eros_temse_hist_05,eros_temse_hist_09]).T
eros_temse_s245 = np.vstack([eros_temse_s245_01,eros_temse_s245_05,eros_temse_s245_09]).T
eros_temse_s585 = np.vstack([eros_temse_s585_01,eros_temse_s585_05,eros_temse_s585_09]).T
eros_temse_s126 = np.vstack([eros_temse_s126_01,eros_temse_s126_05,eros_temse_s126_09]).T

# %% [markdown]
# ## Figures

# %%
def nospines(ax):
    import matplotlib.pyplot as plt
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.yaxis.set_ticks_position('left')
    ax.xaxis.set_ticks_position('bottom')

def noaxes(ax):
    import matplotlib.pyplot as plt
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.spines['left'].set_visible(False)
    plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False)
    plt.tick_params(
    axis='y',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    left=False,      # ticks along the bottom edge are off
    labelleft=False)

width=0.26
fig = plt.figure(figsize=(7,8.0), dpi=90)

i=0
ax = fig.add_subplot(421)
ensse_hist_upper = np.ones((np.shape(years_full)))*(np.nanmean(ensmu_hist[i,:100]+2*ensse_hist[i,:100]))
ensse_hist_lower = np.ones((np.shape(years_full)))*(np.nanmean(ensmu_hist[i,:100]-2*ensse_hist[i,:100]))
plt.axhline(np.nanmean(ensmu_hist[i,:100]+2*ensse_hist[i,:100]), c='grey', lw=2, ls='--')
plt.fill_between(years_hist, ensmu_hist[i,:]-2*ensse_hist[i,:], ensmu_hist[i,:]+2*ensse_hist[i,:], color='k', alpha=0.2, lw=0)
plt.fill_between(years_scen, ensmu_s126[i,:]-2*ensse_s126[i,:], ensmu_s126[i,:]+2*ensse_s126[i,:], color='b', alpha=0.2, lw=0)
plt.fill_between(years_scen, ensmu_s245[i,:]-2*ensse_s245[i,:], ensmu_s245[i,:]+2*ensse_s245[i,:], color='darkorange', alpha=0.3, lw=0)
plt.fill_between(years_scen, ensmu_s585[i,:]-2*ensse_s585[i,:], ensmu_s585[i,:]+2*ensse_s585[i,:], color='r', alpha=0.2, lw=0)
plt.plot(years_hist, ensmu_hist[i,:], 'k')
plt.plot(years_scen, ensmu_s126[i,:], 'b')
plt.plot(years_scen, ensmu_s245[i,:], 'darkorange')
plt.plot(years_scen, ensmu_s585[i,:], 'r')
plt.xlim((1869,2100))
plt.ylim((350,1500))
plt.ylabel('$\overline{T}$ ($^o$C day year$^{-1}$)', fontsize=8)
ax.tick_params(labeltop=False, labelright=False, right=True,labelsize=8)

plt.text(1880,1400,'Historical', c='k')
plt.text(1880,1300,'SSP1-2.6', c='b')
plt.text(1880,1200,'SSP2-4.5', c='darkorange')
plt.text(1880,1100,'SSP5-8.5', c='r')

ax = fig.add_subplot(422)
noaxes(ax)
hist_mu = np.nanmean(ensmu_hist[i,:100])
hist_se = np.nanmean(ensse_hist[i,:100])
s126_mu = np.nanmean(ensmu_s126[i,-20:])
s126_se = np.nanmean(ensse_s126[i,-20:])
s245_mu = np.nanmean(ensmu_s245[i,-20:])
s245_se = np.nanmean(ensse_s245[i,-20:])
s585_mu = np.nanmean(ensmu_s585[i,-20:])
s585_se = np.nanmean(ensse_s585[i,-20:])
plt.plot(0.2, hist_mu, 'o', c='k', lw=0.5, markeredgecolor='w', ms=5)
plt.plot(0.6, s126_mu, 'o', c='b', lw=0.5, markeredgecolor='w', ms=5)
plt.plot(1.0, s245_mu, 'o', c='darkorange', lw=0.5, markeredgecolor='w', ms=5)
plt.plot(1.4, s585_mu, 'o', c='r', lw=0.5, markeredgecolor='w', ms=5)
plt.bar(0.2, 4*hist_se, width, bottom=hist_mu-2*hist_se, color='k', edgecolor='k', lw=0.5)
plt.bar(0.6, 4*s126_se, width, bottom=s126_mu-2*s126_se, color='b', edgecolor='b', lw=0.5)
plt.bar(1.0, 4*s245_se, width, bottom=s245_mu-2*s245_se, color='darkorange', edgecolor='darkorange', lw=0.5)
plt.bar(1.4, 4*s585_se, width, bottom=s585_mu-2*s585_se, color='r', edgecolor='r', lw=0.5)
plt.ylim((350,1500))
plt.xlim((0,12))

i=1
ax = fig.add_subplot(423)
ensse_hist_upper = np.ones((np.shape(years_full)))*(np.nanmean(ensmu_hist[i,:100]+2*ensse_hist[i,:100]))
ensse_hist_lower = np.ones((np.shape(years_full)))*(np.nanmean(ensmu_hist[i,:100]-2*ensse_hist[i,:100]))
plt.axhline(np.nanmean(ensmu_hist[i,:100]+2*ensse_hist[i,:100]), c='grey', lw=2, ls='--')
plt.fill_between(years_hist, ensmu_hist[i,:]-2*ensse_hist[i,:], ensmu_hist[i,:]+2*ensse_hist[i,:], color='k', alpha=0.2, lw=0)
plt.fill_between(years_scen, ensmu_s126[i,:]-2*ensse_s126[i,:], ensmu_s126[i,:]+2*ensse_s126[i,:], color='b', alpha=0.2, lw=0)
plt.fill_between(years_scen, ensmu_s245[i,:]-2*ensse_s245[i,:], ensmu_s245[i,:]+2*ensse_s245[i,:], color='darkorange', alpha=0.3, lw=0)
plt.fill_between(years_scen, ensmu_s585[i,:]-2*ensse_s585[i,:], ensmu_s585[i,:]+2*ensse_s585[i,:], color='r', alpha=0.2, lw=0)
plt.plot(years_hist, ensmu_hist[i,:], 'k')
plt.plot(years_scen, ensmu_s126[i,:], 'b')
plt.plot(years_scen, ensmu_s245[i,:], 'darkorange')
plt.plot(years_scen, ensmu_s585[i,:], 'r')
plt.xlim((1869,2100))
plt.ylim((35,210))
plt.ylabel('$\overline{H}$ (m day year$^{-1}$)', fontsize=8)
ax.tick_params(labeltop=False, labelright=False, right=True,labelsize=8)

ax = fig.add_subplot(424)
noaxes(ax)
hist_mu = np.nanmean(ensmu_hist[i,:100])
hist_se = np.nanmean(ensse_hist[i,:100])
s126_mu = np.nanmean(ensmu_s126[i,-20:])
s126_se = np.nanmean(ensse_s126[i,-20:])
s245_mu = np.nanmean(ensmu_s245[i,-20:])
s245_se = np.nanmean(ensse_s245[i,-20:])
s585_mu = np.nanmean(ensmu_s585[i,-20:])
s585_se = np.nanmean(ensse_s585[i,-20:])
plt.plot(0.2, hist_mu, 'o', c='k', lw=0.5, markeredgecolor='w', ms=5)
plt.plot(0.6, s126_mu, 'o', c='b', lw=0.5, markeredgecolor='w', ms=5)
plt.plot(1.0, s245_mu, 'o', c='darkorange', lw=0.5, markeredgecolor='w', ms=5)
plt.plot(1.4, s585_mu, 'o', c='r', lw=0.5, markeredgecolor='w', ms=5)
plt.bar(0.2, 4*hist_se, width, bottom=hist_mu-2*hist_se, color='k', edgecolor='k', lw=0.5)
plt.bar(0.6, 4*s126_se, width, bottom=s126_mu-2*s126_se, color='b', edgecolor='b', lw=0.5)
plt.bar(1.0, 4*s245_se, width, bottom=s245_mu-2*s245_se, color='darkorange', edgecolor='darkorange', lw=0.5)
plt.bar(1.4, 4*s585_se, width, bottom=s585_mu-2*s585_se, color='r', edgecolor='r', lw=0.5)
plt.ylim((35,210))
plt.xlim((0,12))

i=3
ax = fig.add_subplot(425)
ensse_hist_upper = np.ones((np.shape(years_full)))*(np.nanmean(ensmu_hist[i,:100]+2*ensse_hist[i,:100]))
ensse_hist_lower = np.ones((np.shape(years_full)))*(np.nanmean(ensmu_hist[i,:100]-2*ensse_hist[i,:100]))
plt.axhline(np.nanmean(ensmu_hist[i,:100]+2*ensse_hist[i,:100]), c='grey', lw=2, ls='--')
plt.fill_between(years_hist, ensmu_hist[i,:]-2*ensse_hist[i,:], ensmu_hist[i,:]+2*ensse_hist[i,:], color='k', alpha=0.2, lw=0)
plt.fill_between(years_scen, ensmu_s126[i,:]-2*ensse_s126[i,:], ensmu_s126[i,:]+2*ensse_s126[i,:], color='b', alpha=0.2, lw=0)
plt.fill_between(years_scen, ensmu_s245[i,:]-2*ensse_s245[i,:], ensmu_s245[i,:]+2*ensse_s245[i,:], color='darkorange', alpha=0.3, lw=0)
plt.fill_between(years_scen, ensmu_s585[i,:]-2*ensse_s585[i,:], ensmu_s585[i,:]+2*ensse_s585[i,:], color='r', alpha=0.2, lw=0)
plt.plot(years_hist, ensmu_hist[i,:], 'k')
plt.plot(years_scen, ensmu_s126[i,:], 'b')
plt.plot(years_scen, ensmu_s245[i,:], 'darkorange')
plt.plot(years_scen, ensmu_s585[i,:], 'r')
plt.xlim((1869,2100))
plt.ylim((10,250))
plt.ylabel('$\overline{D}$ (days/year)', fontsize=8)
ax.tick_params(labeltop=False, labelright=False, right=True,labelsize=8)

ax = fig.add_subplot(426)
noaxes(ax)
hist_mu = np.nanmean(ensmu_hist[i,:100])
hist_se = np.nanmean(ensse_hist[i,:100])
s126_mu = np.nanmean(ensmu_s126[i,-20:])
s126_se = np.nanmean(ensse_s126[i,-20:])
s245_mu = np.nanmean(ensmu_s245[i,-20:])
s245_se = np.nanmean(ensse_s245[i,-20:])
s585_mu = np.nanmean(ensmu_s585[i,-20:])
s585_se = np.nanmean(ensse_s585[i,-20:])
plt.plot(0.2, hist_mu, 'o', c='k', lw=0.5, markeredgecolor='w', ms=5)
plt.plot(0.6, s126_mu, 'o', c='b', lw=0.5, markeredgecolor='w', ms=5)
plt.plot(1.0, s245_mu, 'o', c='darkorange', lw=0.5, markeredgecolor='w', ms=5)
plt.plot(1.4, s585_mu, 'o', c='r', lw=0.5, markeredgecolor='w', ms=5)
plt.bar(0.2, 4*hist_se, width, bottom=hist_mu-2*hist_se, color='k', edgecolor='k', lw=0.5)
plt.bar(0.6, 4*s126_se, width, bottom=s126_mu-2*s126_se, color='b', edgecolor='b', lw=0.5)
plt.bar(1.0, 4*s245_se, width, bottom=s245_mu-2*s245_se, color='darkorange', edgecolor='darkorange', lw=0.5)
plt.bar(1.4, 4*s585_se, width, bottom=s585_mu-2*s585_se, color='r', edgecolor='r', lw=0.5)
plt.ylim((10,250))
plt.xlim((0,12))

ax = fig.add_subplot(427)
years_hist_short = np.arange(1850+19,1996+19)
ax.tick_params(labeltop=False, labelright=False, right=True, labelsize=8)

q=1
upper = np.nanmean(erosmu_hist[:-100,q]+2*eros_ensse_hist[:-100,q])
lower = np.nanmean(erosmu_hist[:-100,q]-2*eros_ensse_hist[:-100,q])
upper = np.nanmean(erosmu_hist[:-100,q]+2*(eros_ensse_hist[:-100,q]+eros_temse_hist[:-100,q]))
lower = np.nanmean(erosmu_hist[:-100,q]-2*(eros_ensse_hist[:-100,q]+eros_temse_hist[:-100,q]))

plt.fill_between(years_hist_short, erosmu_hist[:,q]-2*eros_ensse_hist[:,q], erosmu_hist[:,q]+2*eros_ensse_hist[:,q], color='k', alpha=0.2, lw=0)
plt.plot(years_hist_short, erosmu_hist[:,q]-2*(eros_ensse_hist[:,q]+eros_temse_hist[:,q]), '--k', lw=1)
plt.plot(years_hist_short, erosmu_hist[:,q]+2*(eros_ensse_hist[:,q]+eros_temse_hist[:,q]), '--k', lw=1)
plt.fill_between(years_scen, erosmu_s126[:,q]-2*eros_ensse_s126[:,q], erosmu_s126[:,q]+2*eros_ensse_s245[:,q], color='b', alpha=0.2, zorder=90, lw=0)
plt.plot(years_scen, erosmu_s126[:,q]-2*(eros_ensse_s126[:,q]+eros_temse_s126[:,q]), '--', c='b', lw=1)
plt.plot(years_scen, erosmu_s126[:,q]+2*(eros_ensse_s126[:,q]+eros_temse_s126[:,q]), '--', c='b', lw=1)
plt.fill_between(years_scen, erosmu_s245[:,q]-2*eros_ensse_s245[:,q], erosmu_s245[:,q]+2*eros_ensse_s245[:,q], color='darkorange', alpha=0.2, zorder=90, lw=0)
plt.plot(years_scen, erosmu_s245[:,q]-2*(eros_ensse_s245[:,q]+eros_temse_s245[:,q]), '--', c='darkorange', lw=1)
plt.plot(years_scen, erosmu_s245[:,q]+2*(eros_ensse_s245[:,q]+eros_temse_s245[:,q]), '--', c='darkorange', lw=1)
plt.fill_between(years_scen, erosmu_s585[:,q]-2*eros_ensse_s585[:,q], erosmu_s585[:,q]+2*eros_ensse_s585[:,q], color='r', alpha=0.2, lw=0)
plt.plot(years_scen, erosmu_s585[:,q]-2*(eros_ensse_s585[:,q]+eros_temse_s585[:,q]), '--', c='r', lw=1)
plt.plot(years_scen, erosmu_s585[:,q]+2*(eros_ensse_s585[:,q]+eros_temse_s585[:,q]), '--', c='r', lw=1)
plt.plot(years_hist_short, erosmu_hist[:,q], 'k', label='Historical', lw=2, zorder=92)
plt.plot(years_scen, erosmu_s126[:,q], 'b', label='SSP1-2.6', lw=2, zorder=92)
plt.plot(years_scen, erosmu_s245[:,q], 'darkorange', label='SSP2-4.5', lw=2, zorder=92)
plt.plot(years_scen, erosmu_s585[:,q], 'r', label='SSP5-8.5', lw=2, zorder=92)
plt.xlim((1869,2100))
plt.ylabel('$\overline{E}$ (m/year)', fontsize=8)
plt.yticks(np.arange(0,4.5,1), np.arange(0,4.5,1))
plt.ylim((0,4.2))


ax = fig.add_subplot(428)
noaxes(ax)
hist_mu = np.nanmean(erosmu_hist[:100, q])
hist_ensse = np.nanmean(eros_ensse_hist[:100, q])
hist_temse = np.nanmean(eros_temse_hist[:100, q])
s126_mu = np.nanmean(erosmu_s126[-20:, q])
s126_ensse = np.nanmean(eros_ensse_s126[-20:, q])
s126_temse = np.nanmean(eros_temse_s126[-20:, q])
s245_mu = np.nanmean(erosmu_s245[-20:, q])
s245_ensse = np.nanmean(eros_ensse_s245[-20:, q])
s245_temse = np.nanmean(eros_temse_s245[-20:, q])
s585_mu = np.nanmean(erosmu_s585[-20:, q])
s585_ensse = np.nanmean(eros_ensse_s585[-20:, q])
s585_temse = np.nanmean(eros_temse_s585[-20:, q])
plt.plot(0.2, hist_mu, 'o', c='k', lw=0.5, markeredgecolor='w', ms=5)
plt.plot(0.6, s126_mu, 'o', c='b', lw=0.5, markeredgecolor='w', ms=5)
plt.plot(1.0, s245_mu, 'o', c='darkorange', lw=0.5, markeredgecolor='w', ms=5)
plt.plot(1.4, s585_mu, 'o', c='r', lw=0.5, markeredgecolor='w', ms=5)
plt.bar(0.2, 4*hist_ensse, width, bottom=hist_mu-2*hist_ensse, color='k', edgecolor='k', lw=0.5)
plt.bar(0.2, 2*hist_temse, width, bottom=hist_mu-2*hist_ensse-2*hist_temse, color='none', edgecolor='k', lw=0.5)
plt.bar(0.2, 2*hist_temse, width, bottom=hist_mu+2*hist_ensse, color='none', edgecolor='k', lw=0.5)
plt.bar(0.6, 4*s126_ensse, width, bottom=s126_mu-2*s126_ensse, color='b', edgecolor='b', lw=0.5)
plt.bar(0.6, 2*s126_temse, width, bottom=s126_mu-2*s126_ensse-2*s126_temse, color='none', edgecolor='b', lw=0.5)
plt.bar(0.6, 2*s126_temse, width, bottom=s126_mu+2*s126_ensse, color='none', edgecolor='b', lw=0.5)
plt.bar(1.0, 4*s245_ensse, width, bottom=s245_mu-2*s245_ensse, color='darkorange', edgecolor='darkorange', lw=0.5)
plt.bar(1.0, 2*s245_temse, width, bottom=s245_mu-2*s245_ensse-2*s245_temse, color='none', edgecolor='darkorange', lw=0.5)
plt.bar(1.0, 2*s245_temse, width, bottom=s245_mu+2*s245_ensse, color='none', edgecolor='darkorange', lw=0.5)
plt.bar(1.4, 4*s585_ensse, width, bottom=s585_mu-2*s585_ensse, color='r', edgecolor='r', lw=0.5)
plt.bar(1.4, 2*s585_temse, width, bottom=s585_mu-2*s585_ensse-2*s585_temse, color='none', edgecolor='r', lw=0.5)
plt.bar(1.4, 2*s585_temse, width, bottom=s585_mu+2*s585_ensse, color='none', edgecolor='r', lw=0.5)
plt.ylim((0,4.2))
plt.xlim((0,10))

plt.tight_layout()
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.02, hspace=None)
plt.show()

# %%
# Probabilities of emergence
opath='figure_data/'
ofile='prob_emergence_scenarios.nc'
ds = xr.open_dataset(opath+ofile, decode_times=False)
years_hist  = ds['years_hist'].values
years_scen  = ds['years_scen'].values
phist_ensse = ds['phist_ensse'].values
p126s_ensse = ds['p126s_ensse'].values
p245s_ensse = ds['p245s_ensse'].values
p585s_ensse = ds['p585s_ensse'].values
phist_totse = ds['phist_totse'].values
p126s_totse = ds['p126s_totse'].values
p245s_totse = ds['p245s_totse'].values
p585s_totse = ds['p585s_totse'].values

fig = plt.figure(figsize=(7,7.0), dpi=90)
ax = fig.add_subplot(427)
nospines(ax)

plt.axhline(90,ls='-',c='grey',lw=0.5)
plt.axhline(66,ls='-',c='grey',lw=0.5)
plt.plot(years_hist, phist_ensse, ls='-', c='k', lw=1)
plt.plot(years_scen, p126s_ensse, ls='-', c='b', lw=1)
plt.plot(years_scen, p245s_ensse, ls='-', c='darkorange', lw=1)
plt.plot(years_scen, p585s_ensse, ls='-', c='r', lw=1)
plt.plot(years_hist, phist_totse, ls='--', c='k', lw=1)
plt.plot(years_scen, p126s_totse, ls='--', c='b', lw=1)
plt.plot(years_scen, p245s_totse, ls='--', c='darkorange', lw=1)
plt.plot(years_scen, p585s_totse, ls='--', c='r', lw=1)

plt.ylabel('%', fontsize=8)
plt.ylim((0, 101))
plt.text(2010, 105, '', c='k')
plt.yticks(np.arange(0,125,25), fontsize=8)
plt.xticks(np.arange(1900,2150,50), fontsize=8)
plt.xlim((1869,2100))

plt.tight_layout()
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.02, hspace=None)
plt.show()
